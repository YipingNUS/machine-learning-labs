# %% [markdown]
# <a href="https://colab.research.google.com/github/YipingNUS/machine-learning-labs/blob/master/lab2_linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

#the usual suspects
import math
import random
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# In this lab, we'll use the same logistic regression model to classify one toy dataset and another slightly more realistic dataset. You'll realize that the same model can solve both problems with minimum modification.

# %% [markdown]
# # Toy Dataset
#
# The example is taken from [Tensorflow Playground](https://playground.tensorflow.org/). Please use sklearn to build a model and classify the following toy dataset.

# %%
#input x is some random numbers between 0 and 1
batch_size = 100
#x = torch.rand(batch_size,1,requires_grad=True) 
x_0 = np.zeros((batch_size,2)) + np.random.randn(batch_size,2)/5
y_0 = np.zeros(batch_size)
x_1 = np.ones((batch_size,2)) + np.random.randn(batch_size,2)/5
y_1 = np.ones(batch_size)

# %%
#create our own y_true as identity relationship to x with some random noise
plt.scatter(x_0[:,0], x_0[:,1])
plt.scatter(x_1[:,0], x_1[:,1])

# %%
x = np.concatenate((x_0, x_1))
y_true = np.concatenate((y_0, y_1))
print(x.shape)
print(y_true.shape)
# Out:
# (200, 2)
# (200,)

# %% [markdown]
# ## Task 1: Train a linear classifier to classify the data
#
# Requirements:
# 1. Use `sklearn` library and select an appropriate classifier.
# 2. Inspect what's the **cost function** being used and report the loss.
# 3. Plot the decision boundary as a straight line over the data to show that the classification makes sense.

# %%
# TODO: your code here

# %% [markdown]
# # "Real-world" Data
#
# In this task, you'll work on a slightly more realistic task: classifying breast cancer. You're required to use [Tensorflow](https://www.tensorflow.org/tutorials/quickstart/beginner), which has a slightly different flavour than `PyTorch`, but the essense is the same.
#
# I won't be teaching you the basics on Tensorflow in the lab. You can go through the tutorials in the link above. Learning from the tutorials and documentations is an essential skill in machine learning.

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()

# %%
# TODO: checkout the documentation and explore the data object, see what's included and how to proceed from here.
# Hint: check what are the attributes, how the values look like and manually go through a few examples

# %%
# TODO: split the data input training and testing set
# Hint: from sklearn.model_selection import train_test_split

# %%
# TODO: scale the data to range [-1, 1]
# Hint: from sklearn.preprocessing import StandardScaler
# It's also a good exercise to see what if you don't scale the data

# %%
# TODO: build your simple Keras model and train it

# %%
# TODO: evaluate the loss and accuracy in the training and test set

# %%
# TODO: plot the learning curve for the loss function and accuracy in two separate charts. 
# (You need to include the line for both training and testing)

# %%
# TODO: save the model to your local machine from colab and load it back

# %% [markdown]
# ## Additional Courses to Learn Tensorflow
#
# 1. [Tensorflow in practice specialization](https://www.coursera.org/specializations/tensorflow-in-practice)
#   * Free to audit.
# 2. [Tensorflow 2.0: Deep Learning and Artificial Intelligence](https://www.udemy.com/course/deep-learning-tensorflow-2/)
#   * Not free. I purchased for $10 when it had discount.
